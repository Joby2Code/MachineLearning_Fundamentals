# %%
import tensorflow as tf
# Out:
# /Users/joby/anaconda/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# <b> Testing tensorflow installation </b>

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=5)
model.evaluate(x_test, y_test)
# Out:
# ...
# 11493376/11490434 [==============================] - 1s 0us/step
# Epoch 1/5
# 60000/60000 [==============================] - 11s 188us/step - loss: 0.2203 - acc: 0.9344
# Epoch 2/5
# 60000/60000 [==============================] - 12s 205us/step - loss: 0.0962 - acc: 0.9708
# Epoch 3/5
# 60000/60000 [==============================] - 13s 208us/step - loss: 0.0700 - acc: 0.9779
# Epoch 4/5
# 60000/60000 [==============================] - 13s 209us/step - loss: 0.0537 - acc: 0.9823
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 1s 58us/step
# [0.06861765717036324, 0.9787]

# %%
a = tf.constant(3.0,tf.float32) # Defining a constant
print(a)
# Out:
# Tensor("Const_5:0", shape=(), dtype=float32)

# %%
V = tf.Variable([3],tf.float32) # Defining a Variable
print(V)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=int32_ref>

# %%
p = tf.placeholder(tf.float32)
print(p)
# Out:
# Tensor("Placeholder:0", dtype=float32)

# %%
zero = tf.Variable(4)
one = tf.constant(1)
val = tf.add(zero,one)

print(val)
# Out:
# Tensor("Add_2:0", shape=(), dtype=int32)

# %%
new_var = tf.assign(zero,val)
print(new_var)
# Out:
# Tensor("Assign:0", shape=(), dtype=int32_ref)

# %%
init_op = tf.global_variables_initializer() # initialize variables

# %%
sess = tf.Session()
sess.run(init_op) # everything is executed in a session

# %%
print(sess.run(new_var))
# Out:
# 6

# %%
hello = tf.constant('Hello')
world = tf.constant('Wrold')
concat = tf.add(hello,world)
print(sess.run(concat))
# Out:
# b'HelloWrold'

# %% [markdown]
# Placeholder

# %%
a = tf.placeholder(tf.float32)

# %%
b = a*2

# %%
result = sess.run(b,feed_dict={a:3})
print(result)
# Out:
# 6.0

# %%
result = sess.run(b,feed_dict={a:[3,6,7]})
print(result)
# Out:
# [ 6. 12. 14.]

# %%
sess.close()

# %%
with tf.Session() as sess:
    result = sess.run(b,feed_dict={a:[3,6,7]})
    print(result)
# Out:
# [ 6. 12. 14.]

# %%
graph = tf.get_default_graph()
graph.get_operations() # shows the list of operations performed on the graph
