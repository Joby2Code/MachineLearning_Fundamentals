# %%
import pandas as pd

df = pd.read_csv('nyc_weather.csv', na_values={
    'Temperature':['test'],
    'Humidity':[52]    
});
df['Events'].fillna('No Events',inplace=True)
df.fillna(0.0,inplace=True)
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23       0.0                 30.03
# 1  1/2/2016           36        18      46.0                 30.02
# 2  1/3/2016           40        21      47.0                 29.86
# 3  1/4/2016           25         9      44.0                 30.05
# 4  1/5/2016           20        -3      41.0                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover     Events  \
# 0               10           8.0               0           5  No Events
# 1               10           7.0               0           3  No Events
# 2               10           8.0               0           1  No Events
# 3               10           9.0               0           3  No Events
# 4               10           5.0               0           0  No Events
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df['EST'][df['Events'] == 'Rain']

# %%
#Finding the table dimension
row,col = df.shape
#Finding the range of the row elements 
df[2:5]

# %%
df.columns # Print the column values
df.est #df['EST']

# %%
df[['EST','Temperature','Humidity']].head().describe # Printing only certain columns
# Out:
# <bound method NDFrame.describe of         EST  Temperature  Humidity
# 0  1/1/2016           38        52
# 1  1/2/2016           36        46
# 2  1/3/2016           40        47
# 3  1/4/2016           25        44
# 4  1/5/2016           20        41>

# %%
df.index
df.set_index('EST',inplace=True) # Set a new index
df.loc['1/1/2016'] # Find the data corresponding to the new key as per the tr
# Out:
# Temperature                38
# DewPoint                   23
# Humidity                   52
# Sea Level PressureIn    30.03
# VisibilityMiles            10
# WindSpeedMPH                8
# PrecipitationIn             0
# CloudCover                  5
# Events                      0
# WindDirDegrees            281
# Name: 1/1/2016, dtype: object

# %%
df.reset_index(inplace=True) # This is to replace the index back to the original
df.head()
# Out:
#    index       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0      0  1/1/2016           38        23        52                 30.03
# 1      1  1/2/2016           36        18        46                 30.02
# 2      2  1/3/2016           40        21        47                 29.86
# 3      3  1/4/2016           25         9        44                 30.05
# 4      4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5      0
# 1               10           7.0               0           3      0
# 2               10           8.0               0           1      0
# 3               10           9.0               0           3      0
# 4               10           5.0               0           0      0
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# ...

# %%
df.iloc[2:4] # To slice data
# Out:
#    index       EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2      2  1/3/2016           40        21        47                 29.86
# 3      3  1/4/2016           25         9        44                 30.05
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1      0
# 3               10           9.0               0           3      0
#
#    WindDirDegrees
# 2             277
# 3             345

# %%
df.to_excel("weather.xlsx",sheet_name="weeather",startrow=1,startcol=3,index=False);

# %%
df_stocks = pd.DataFrame({
    'tickers':['Google','Microsoft','Adobe'],
    'price':[20,30,40],
    'dividends':[0.01,1,100]
})

df_weather = pd.DataFrame({
    'days':['Monday','Tuesday','Wednesday'],
    'temperature':['',30,50],
    'humidity':[35,89,9]
})

df_weather
# Out:
#         days  humidity temperature
# 0     Monday        35
# 1    Tuesday        89          30
# 2  Wednesday         9          50

# %%
#Adding multiple dataframes
with pd.ExcelWriter('stock_weather.xlsx') as writer:
    df_stocks.to_excel(writer,sheet_name='stocks')
    df_weather.to_excel(writer,sheet_name='weather')

# %%
df_weather.fillna(0.0)
df_weather.fillna(method='ffill',inplace=True)
df_weather.interpolate()
df_weather
# Out:
#         days  humidity temperature
# 0     Monday        35
# 1    Tuesday        89          30
# 2  Wednesday         9          50

# %%
import numpy as np
new_df = df_weather.dropna()
new_df.replace('',np.NaN)
new_df.interpolate()
# Out:
#         days  humidity temperature
# 0     Monday        35
# 1    Tuesday        89          30
# 2  Wednesday         9          50

# %%
df.head(5)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23       0.0                 30.03
# 1  1/2/2016           36        18      46.0                 30.02
# 2  1/3/2016           40        21      47.0                 29.86
# 3  1/4/2016           25         9      44.0                 30.05
# 4  1/5/2016           20        -3      41.0                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover     Events  \
# 0               10           8.0               0           5  No Events
# 1               10           7.0               0           3  No Events
# 2               10           8.0               0           1  No Events
# 3               10           9.0               0           3  No Events
# 4               10           5.0               0           0  No Events
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
event = df.groupby('Events')

for Events,Temperature in event:
    print (Events)
    #print (Temperature)

df_rain = event.get_group('Rain') # This creates a group by

df_rain.max()

event.min()
# Out:
# Fog-Snow
# No Events
# Rain
# Snow
#                  EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Events
# Fog-Snow   1/17/2016           26        21      66.0                 29.77
# No Events   1/1/2016           20        -3       0.0                 29.58
# Rain       1/10/2016           41        22      45.0                 29.52
# Snow       1/18/2016           25         6      41.0                 29.83
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# Events
# Fog-Snow                 1           6.0            0.05           6
# No Events                9           0.0               0           0
# Rain                     4           0.0            0.24           3
# Snow                     8           0.0            0.01           2
#
#            WindDirDegrees
# Events
# Fog-Snow               42
# No Events              79
# Rain                   76
# Snow                   34

# %%
event.describe()
# Out:
#           CloudCover                                               DewPoint  \
#                count      mean       std  min  25%  50%   75%  max    count
# Events
# Fog-Snow         2.0  7.000000  1.414214  6.0  6.5  7.0  7.50  8.0      2.0
# No Events       22.0  2.272727  2.229282  0.0  1.0  2.0  3.00  8.0     22.0
# Rain             4.0  6.250000  2.217356  3.0  6.0  7.0  7.25  8.0      4.0
# Snow             3.0  2.666667  0.577350  2.0  2.5  3.0  3.00  3.0      3.0
#
#                       ...  WindDirDegrees        WindSpeedMPH             \
#                 mean  ...             75%    max        count       mean
# Events                ...
# Fog-Snow   22.000000  ...          269.25  345.0          2.0  11.000000
# No Events  15.590909  ...          293.00  345.0         22.0   5.954545
# Rain       35.750000  ...          318.25  340.0          4.0   5.500000
# Snow        7.666667  ...          310.00  327.0          3.0   6.000000
#
#
# ...

# %%
#Concatenate Dataframe
df_cncat = pd.concat([df_stocks,df_weather],keys=['stocks','weather'],axis=1)
df_cncat
#df_cncat.to_csv('test.csv')
# Out:
#      stocks                     weather
#   dividends price    tickers       days humidity temperature
# 0      0.01    20     Google     Monday       35
# 1      1.00    30  Microsoft    Tuesday       89          30
# 2    100.00    40      Adobe  Wednesday        9          50

# %%
df.head()
df.pivot(index='EST',columns='Events',values='Temperature').head(5).fillna('unavailable')
# Out:
# Events        Fog-Snow    No Events         Rain         Snow
# EST
# 1/1/2016   unavailable           38  unavailable  unavailable
# 1/10/2016  unavailable  unavailable           50  unavailable
# 1/11/2016  unavailable           33  unavailable  unavailable
# 1/12/2016  unavailable           35  unavailable  unavailable
# 1/13/2016  unavailable           26  unavailable  unavailable
